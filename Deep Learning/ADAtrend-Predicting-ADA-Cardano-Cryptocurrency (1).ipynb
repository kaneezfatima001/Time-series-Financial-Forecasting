# %% [markdown]
# # **Title: ADATrend - Predicting ADA (Cardano) Cryptocurrency Prices and Exploring Factors Influencing Market Trends**

# %% [markdown]
# ![Screenshot 2023-07-11 170516.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction:
# Cryptocurrencies have revolutionized the financial world, gaining significant attention and becoming a topic of interest for investors, traders, and technology enthusiasts. In this AI project, we aim to analyze and predict cryptocurrency prices, focusing on the ADA (Cardano) coin. By leveraging historical price data and exploring various factors affecting the market, we can gain valuable insights to make informed investment decisions and understand the dynamics of this rapidly evolving industry.
#
# ## Problem Statement:
# The volatile nature of cryptocurrency markets poses challenges for investors and traders who seek to optimize their decision-making process. The problem at hand is to develop an AI model that can accurately predict the price movements of the ADA coin based on historical data. Additionally, we aim to identify and analyze the key factors that influence cryptocurrency prices, shedding light on the underlying dynamics and enabling us to make more informed predictions about future market trends.
#
# ## Objectives:
# 1. Build a predictive model: Develop an AI model that utilizes historical price data to predict future price movements of the ADA coin accurately. By leveraging machine learning algorithms and statistical techniques, we aim to create a robust model that captures the complex patterns and dynamics of the cryptocurrency market.
#
# 2. Identify influential factors: Explore the various parameters associated with the ADA coin, such as opening price, highest price, lowest price, closing price, volume of transactions, and market capitalization. Analyze their impact on the price fluctuations and identify the most influential factors driving the cryptocurrency market.
#
# 3. Provide actionable insights: Equip investors, traders, and cryptocurrency enthusiasts with valuable insights derived from our analysis. By understanding the factors that influence price trends, users can make more informed decisions, manage risks effectively, and potentially capitalize on market opportunities.
#
# ## Dataset Description:
# The dataset used in this project comprises CSV files containing the historical price information of select cryptocurrencies with a focus on the ADA (Cardano) coin. Each file represents the price history of a specific currency and includes data from April 28, 2013, onwards. The dataset provides daily observations of the following parameters:
#
# - Date: The date of observation
# - Open: The opening price of the coin on the given day
# - High: The highest price reached by the coin on the given day
# - Low: The lowest price reached by the coin on the given day
# - Close: The closing price of the coin on the given day
# - Volume: The volume of transactions conducted on the given day
# - Market Cap: The market capitalization of the cryptocurrency in USD
#
# By analyzing this dataset, we can uncover trends, patterns, and relationships within the ADA coin's price history, allowing us to develop an accurate predictive model and gain insights into the broader cryptocurrency market.

# %% [markdown]
# # Technologies Used
#
# 1. Python: The project is implemented using the Python programming language, which provides a wide range of libraries and tools for data analysis, machine learning, and deep learning.
#
# 2. Pandas: The Pandas library is used for data manipulation and analysis. It provides data structures and functions for efficiently handling and processing the cryptocurrency price dataset.
#
# 3. NumPy: NumPy is used for numerical computations and operations on arrays. It is particularly useful for handling multidimensional arrays and mathematical calculations required in the project.
#
# 4. Matplotlib: Matplotlib is a plotting library in Python. It is used for creating visualizations and charts to analyze and visualize the cryptocurrency price data.
#
# 5. TensorFlow: TensorFlow is an open-source machine learning framework. It is used to build and train deep learning models, including LSTM (Long Short-Term Memory) models, for predicting cryptocurrency prices.
#
# 6. Keras: Keras is a high-level neural networks API that runs on top of TensorFlow. It simplifies the process of building deep learning models by providing a user-friendly interface.
#
# 7. scikit-learn: scikit-learn is a machine learning library in Python. It is used for preprocessing the data, splitting it into training and testing sets, and evaluating the performance of the models.
#
# # Methodology
#
# The project follows a systematic methodology to analyze and predict cryptocurrency prices, considering both univariate and multivariate aspects. The process involves several key steps:
#
# 1. Data Preprocessing: The dataset is preprocessed to ensure its quality and suitability for analysis. This includes handling missing values, parsing dates, converting data types, and scaling the data if necessary.
#
# 2. Exploratory Data Analysis: The dataset is analyzed to gain insights into the cryptocurrency market. Visualizations and statistical techniques are used to identify patterns, trends, and relationships between variables. This helps understand the factors influencing the price fluctuations of the ADA coin.
#
# 3. Model Development: Various machine learning and deep learning models are implemented to predict cryptocurrency prices. Different models, including naive forecasts, dense models, Conv1D models, and LSTM models, are built and trained on the historical price data. These models capture the complex patterns and dynamics of the cryptocurrency market.
#
# 4. Model Evaluation: The performance of the models is evaluated using appropriate evaluation metrics such as mean absolute error (MAE), mean squared error (MSE), root mean squared error (RMSE), mean absolute percentage error (MAPE), and mean absolute scaled error (MASE). This allows comparison and selection of the best-performing model.
#
# 5. Ensemble Modeling: Ensemble modeling techniques are employed to combine predictions from multiple models, enhancing the overall predictive power. The ensemble model leverages different loss functions and combines the predictions to improve accuracy and stability.
#
#
#
# # Results: Univariate Analysis
#
# In the univariate analysis, we evaluated the performance of various models for predicting the price of Cardano (ADA) cryptocurrency. Here's a summary of the results from the univariate analysis in the form of a table:
#
# | Model                   | MAE     | MSE     | RMSE    | MAPE       | MASE      |
# |-------------------------|---------|---------|---------|------------|-----------|
# | Naïve Model             | 0.045757| 0.006606| 0.081276| 5.2312446% | 0.996727  |
# | Ensemble Model          | 0.047482| 0.006545| 0.080901| 5.4122233% | 1.034289  |
# | Model 1 (Window Size 7) | 0.048121| 0.006981| 0.083552| 5.453406%  | 1.048219  |
# | Model 2 (Window Size 30)| 0.051317| 0.007094| 0.084225| 6.279604%  | 1.098559  |
# | Model 3 (Window Size 30)| 0.114309| 0.033605| 0.133529| 12.707392% | 2.457961  |
# | Model 4 (Conv1D)        | 0.10605 | 0.029121| 0.117015| 11.44943%  | 2.31009   |
# | Model 5 (LSTM)          | 0.062244| 0.011427| 0.106897| 6.806477%  | 1.355862  |
#
#
# # Discussion/Interpretation of Results: Univariate Analysis
#
# Based on the results, we can make the following observations:
#
# The analysis of various models for predicting the price of Cardano (ADA) cryptocurrency reveals notable insights. The Naïve Model serves as a reasonable baseline, indicating price persistence. The ensemble model achieves comparable performance, highlighting the benefits of combining models. Dense neural network models show similar performance, with a smaller window size performing better for next-day predictions. However, predicting prices further into the future proves challenging, as seen in Model 3 with a larger window size and 7-day horizon.
#
# The Conv1D model performs relatively poorly, while the LSTM model demonstrates competitive performance, showcasing the effectiveness of capturing sequential dependencies in time series data. These findings enhance our understanding of model performance and provide valuable insights for improving cryptocurrency price predictions.
#
# # Results: Multivariate Analysis
#
# In the multivariate analysis, we extended the forecasting task by incorporating additional input features such as 'Open', 'Low', 'High', and 'Volume' along with the target variable 'Close'. The LSTM model was trained on this augmented dataset, and the performance was evaluated.
#
# The LSTM model achieved a training score (RMSE) of 0.03 and a test score (RMSE) of 0.28.
#
# # Discussion/Interpretation of Results: Multivariate Analysis
#
# The multivariate analysis results indicate that incorporating additional input features improves the predictive performance of the LSTM model. By considering multiple variables related to the cryptocurrency market, the model gains more comprehensive information for making predictions. The relatively low training score and slightly higher test score suggest that the model is able to generalize well to unseen data and capture meaningful relationships between the input features and the target variable.
#
# # Conclusion
#
# In this study, we applied various machine learning models for the task of cryptocurrency price prediction. The univariate analysis revealed that models such as dense neural networks and LSTM are effective in capturing the temporal patterns in the price data. Additionally, the multivariate analysis demonstrated that incorporating additional market-related features enhances the predictive performance.
#
# Among the models evaluated, the ensemble model, the naive model, and Model 1 (dense neural network with a window size of 7 and horizon of 1) demonstrated the best performance in terms of accuracy metrics. These models can serve as reliable tools for forecasting the price of Cardano cryptocurrency. Further research and experimentation can be conducted to optimize the models and explore additional techniques for improving the prediction accuracy.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %% [markdown]
# **Import with Pandas**
#
# The following code shows the import of the pandas library and reads a CSV file named "coin_Cardano.csv" using the read_csv() function. It stores the data in a DataFrame called df and displays the first few rows using the head() function.

# %%
import pandas as pd

df = pd.read_csv("coin_Cardano.csv")
df.head()
# Out:
#    SNo     Name Symbol                 Date      High       Low      Open  \
# 0    1  Cardano    ADA  2017-10-02 23:59:59  0.030088  0.019969  0.024607
# 1    2  Cardano    ADA  2017-10-03 23:59:59  0.027425  0.020690  0.025757
# 2    3  Cardano    ADA  2017-10-04 23:59:59  0.022806  0.020864  0.020864
# 3    4  Cardano    ADA  2017-10-05 23:59:59  0.022154  0.020859  0.021951
# 4    5  Cardano    ADA  2017-10-06 23:59:59  0.021542  0.018360  0.021359
#
#       Close      Volume     Marketcap
# 0  0.025932  57641300.0  6.288991e+08
# 1  0.020816  16997800.0  5.396927e+08
# 2  0.021931   9000050.0  5.686195e+08
# 3  0.021489   5562510.0  5.571390e+08
# 4  0.018539   7780710.0  4.806646e+08

# %%
qr=df.Date.values

# %% [markdown]
# **Rmeove Hour-Minute-Seconds in Date index**
#
# This code preprocesses the data by parsing the dates in the DataFrame. It removes the time part from the "Date" column and sets it as the index. It then displays the first few rows of the modified DataFrame.

# %%
# Parse dates
df = pd.read_csv("coin_Cardano.csv", parse_dates=["Date"])

# Remove time part from 'Date' and set 'Date' as index
df['Date'] = df['Date'].dt.date
df.set_index('Date', inplace=True)

df.head()
# Out:
#             SNo     Name Symbol      High       Low      Open     Close  \
# Date
# 2017-10-02    1  Cardano    ADA  0.030088  0.019969  0.024607  0.025932
# 2017-10-03    2  Cardano    ADA  0.027425  0.020690  0.025757  0.020816
# 2017-10-04    3  Cardano    ADA  0.022806  0.020864  0.020864  0.021931
# 2017-10-05    4  Cardano    ADA  0.022154  0.020859  0.021951  0.021489
# 2017-10-06    5  Cardano    ADA  0.021542  0.018360  0.021359  0.018539
#
#                 Volume     Marketcap
# Date
# 2017-10-02  57641300.0  6.288991e+08
# 2017-10-03  16997800.0  5.396927e+08
# 2017-10-04   9000050.0  5.686195e+08
# 2017-10-05   5562510.0  5.571390e+08
# 2017-10-06   7780710.0  4.806646e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1374 entries, 2017-10-02 to 2021-07-06
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        1374 non-null   int64
#  1   Name       1374 non-null   object
#  2   Symbol     1374 non-null   object
#  3   High       1374 non-null   float64
#  4   Low        1374 non-null   float64
#  5   Open       1374 non-null   float64
#  6   Close      1374 non-null   float64
#  7   Volume     1374 non-null   float64
#  8   Marketcap  1374 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 107.3+ KB

# %%
# How many samples do we have?
len(df)
# Out:
# 1374

# %% [markdown]
# The next code creates a new DataFrame containing only the "Close" price column from the original data. It renames the column as "Price" and displays the first few rows of the new DataFrame.

# %%
# Only want closing price for each day
ada_prices = pd.DataFrame(df["Close"]).rename(columns={"Close": "Price"})
ada_prices.head()
# Out:
#                Price
# Date
# 2017-10-02  0.025932
# 2017-10-03  0.020816
# 2017-10-04  0.021931
# 2017-10-05  0.021489
# 2017-10-06  0.018539

# %% [markdown]
# The following code imports the matplotlib.pyplot library and plots the "Price" column from the DataFrame. It sets the figure size, adds labels and a title to the plot, and displays the plot.

# %%
import matplotlib.pyplot as plt
ada_prices.plot(figsize=(10, 7))
plt.ylabel("ADA Price")
plt.title("Price of ADA from 2017-10-02 to 2021-07-06", fontsize=16)
plt.legend(fontsize=14);

# %% [markdown]
# **Importing time series data with Python's CSV module**
#
# The code assigns the file path of the CSV file to the variable "DATA_DIR".
#
# The next code imports the csv module and opens the CSV file specified by "DATA_DIR". It reads the file using a CSV reader object and prints the column names. It also finds the indices of the columns with names "Date" and "Close" and prints them.

# %%
DATA_DIR="coin_Cardano.csv"

# %%
import csv

# Open the CSV file
with open(DATA_DIR, "r") as f:

    # Create a CSV reader object
    reader = csv.reader(f)

    # Read the first row (header) of the CSV file
    header = next(reader)

    # Print the column names
    print(header)

    # Find the indices of columns with names "Date" and "Close"
    date_index = header.index("Date")
    price_index = header.index("Close")

    # Print the indices for columns "Date" and "Close"
    print("Index for column 'Date':", date_index)
    print("Index for column 'Price':", price_index)
# Out:
# ['SNo', 'Name', 'Symbol', 'Date', 'High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap']
# Index for column 'Date': 3
# Index for column 'Price': 7

# %% [markdown]
# In this code, a CSV file is read using the csv module and the datetime module is imported. The code extracts date strings and converts them to datetime objects. It also collects the closing prices as floats. The first 10 elements of the date and price lists are displayed.

# %%
import csv
from datetime import datetime

timesteps = []
ada_price = []
with open(DATA_DIR, "r") as f:
  csv_reader = csv.reader(f, delimiter=",") # read in the target CSV
  next(csv_reader) # skip first line (this gets rid of the column titles)
  for line in csv_reader:
    date_string = line[3]
    date_without_time = date_string[:10]  # take only the first 10 characters (the date part)
    timesteps.append(datetime.strptime(date_without_time, "%Y-%m-%d")) # get the dates as dates (not strings)
    ada_price.append(float(line[7])) # get the closing price as float

# View first 10 of each
timesteps[:10], ada_price[:10]
# Out:
# ([datetime.datetime(2017, 10, 2, 0, 0),
#   datetime.datetime(2017, 10, 3, 0, 0),
#   datetime.datetime(2017, 10, 4, 0, 0),
#   datetime.datetime(2017, 10, 5, 0, 0),
#   datetime.datetime(2017, 10, 6, 0, 0),
#   datetime.datetime(2017, 10, 7, 0, 0),
#   datetime.datetime(2017, 10, 8, 0, 0),
#   datetime.datetime(2017, 10, 9, 0, 0),
#   datetime.datetime(2017, 10, 10, 0, 0),
#   datetime.datetime(2017, 10, 11, 0, 0)],
#  [0.02593179978430271,
#   0.02081580087542534,
#   0.021931499242782593,
#   0.021488700062036514,
#   0.018539100885391235,
#   0.02094089984893799,
#   0.02047719992697239,
#   0.022113699465990067,
#   0.021531300619244576,
#   0.02251950092613697])

# %% [markdown]
# Now we will perform the following code. It plots the date and price data from the CSV file. It sets the figure size, adds a title, and labels to the plot, and displays the plot.

# %%
# Plot from CSV
plt.figure(figsize=(10, 7))
plt.plot(timesteps, ada_price)
plt.title("Price of ADA from 2017-10-02 to 2021-07-06", fontsize=16)
plt.xlabel("Date")
plt.ylabel("ADA Price");

# %% [markdown]
# **Back to pandas**

# %%
ada_prices.head()
# Out:
#                Price
# Date
# 2017-10-02  0.025932
# 2017-10-03  0.020816
# 2017-10-04  0.021931
# 2017-10-05  0.021489
# 2017-10-06  0.018539

# %% [markdown]
# Here, the code retrieves the date array and the "Price" column as NumPy arrays. The first 10 elements of both arrays are displayed.

# %%
# Get ADA date array
timesteps = ada_prices.index.to_numpy()
prices = ada_prices["Price"].to_numpy()

timesteps[:10], prices[:10]
# Out:
# (array([datetime.date(2017, 10, 2), datetime.date(2017, 10, 3),
#         datetime.date(2017, 10, 4), datetime.date(2017, 10, 5),
#         datetime.date(2017, 10, 6), datetime.date(2017, 10, 7),
#         datetime.date(2017, 10, 8), datetime.date(2017, 10, 9),
#         datetime.date(2017, 10, 10), datetime.date(2017, 10, 11)],
#        dtype=object),
#  array([0.0259318, 0.0208158, 0.0219315, 0.0214887, 0.0185391, 0.0209409,
#         0.0204772, 0.0221137, 0.0215313, 0.0225195]))

# %% [markdown]
# **Create train & test sets for time series**
#
# The following code creates train and test data splits for time series data. It determines the split size based on the length of the prices array and creates the train data splits (everything before the split) and the test data splits (everything after the split). It then displays the lengths of the train and test data.

# %%
# Create train and test splits the right way for time series data
split_size = int(0.8 * len(prices)) # 80% train, 20% test

# Create train data splits (everything before the split)
X_train, y_train = timesteps[:split_size], prices[:split_size]

# Create test data splits (everything after the split)
X_test, y_test = timesteps[split_size:], prices[split_size:]

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (1099, 275, 1099, 275)

# %% [markdown]
# The code defines a function called "plot_time_series" that plots a series of timesteps against corresponding values. It takes arrays of timesteps and values as input, along with optional parameters for formatting, start and end indices, and a label.

# %%
# Create a function to plot time series data
def plot_time_series(timesteps, values, format='.', start=0, end=None, label=None):
  """
  Plots a timesteps (a series of points in time) against values (a series of values across timesteps).

  Parameters
  ---------
  timesteps : array of timesteps
  values : array of values across time
  format : style of plot, default "."
  start : where to start the plot (setting a value will index from start of timesteps & values)
  end : where to end the plot (setting a value will index from end of timesteps & values)
  label : label to show on plot of values
  """
  # Plot the series
  plt.plot(timesteps[start:end], values[start:end], format, label=label)
  plt.xlabel("Time")
  plt.ylabel("ADA Price")
  if label:
    plt.legend(fontsize=14) # make label bigger
  plt.grid(True)

# %% [markdown]
# Now we will try out the plotting function. It creates a figure, calls the "plot_time_series" function twice to plot the train and test data, and adds labels to the plot.

# %%
# Try out our plotting function
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_train, values=y_train, label="Train data")
plot_time_series(timesteps=X_test, values=y_test, label="Test data")

# %% [markdown]
# **Model 0: Naïve forecast (baseline)**
#
# The following code creates a naive forecast by taking all values from the test data except the last one.

# %%
# Create a naïve forecast
naive_forecast = y_test[:-1] # Naïve forecast equals every value excluding the last value
naive_forecast[:10], naive_forecast[-10:] # View frist 10 and last 10
# Out:
# (array([0.09754411, 0.09280763, 0.09380031, 0.09615203, 0.10192532,
#         0.10502489, 0.10653755, 0.1100344 , 0.10885216, 0.10729689]),
#  array([1.25043983, 1.33520171, 1.32475207, 1.36843749, 1.3834715 ,
#         1.33561147, 1.39439704, 1.40683592, 1.4581844 , 1.4048981 ]))

# %% [markdown]
# The code plots the naive forecast along with the train and test data using the "plot_time_series" function.

# %%
# Plot naive forecast
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_train, values=y_train, label="Train data")
plot_time_series(timesteps=X_test, values=y_test, label="Test data")
plot_time_series(timesteps=X_test[1:], values=naive_forecast, format="-", label="Naive forecast");

# %% [markdown]
# Now we will perform the following code. It creates a figure, sets an offset value, and plots the test data and the naive forecast with the specified offset using the "plot_time_series" function.

# %%
plt.figure(figsize=(10, 7))
offset = 150 # offset the values by 300 timesteps
plot_time_series(timesteps=X_test, values=y_test, start=offset, label="Test data")
plot_time_series(timesteps=X_test[1:], values=naive_forecast, format="-", start=offset, label="Naive forecast");

# %%
# Let's get TensorFlow!
import tensorflow as tf
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# The next code defines a function called "mean_absolute_scaled_error" (MASE) for evaluating the performance of a forecast. It calculates the mean absolute error (MAE) and the MAE of a naive forecast (assuming no seasonality) and returns the ratio of the two. The code defines another function called "evaluate_preds" that calculates various metrics for evaluating forecast predictions. It takes the true values and predicted values as input and returns the calculated metrics as a dictionary.

# %%
# MASE implemented courtesy of sktime - https://github.com/alan-turing-institute/sktime/blob/ee7a06843a44f4aaec7582d847e36073a9ab0566/sktime/performance_metrics/forecasting/_functions.py#L16
def mean_absolute_scaled_error(y_true, y_pred):
  """
  Implement MASE (assuming no seasonality of data).
  """
  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  # Find MAE of naive forecast (no seasonality)
  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

  return mae / mae_naive_no_season

# %%
def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  y_true = tf.cast(y_true, dtype=tf.float32)
  y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
  mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)
  rmse = tf.sqrt(mse)
  mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
  mase = mean_absolute_scaled_error(y_true, y_pred)

  # Account for different sized metrics (for longer horizons, reduce to single number)
  if mae.ndim > 0: # if mae isn't already a scalar, reduce it to one by aggregating tensors to mean
    mae = tf.reduce_mean(mae)
    mse = tf.reduce_mean(mse)
    rmse = tf.reduce_mean(rmse)
    mape = tf.reduce_mean(mape)
    mase = tf.reduce_mean(mase)

  return {"mae": mae.numpy(),
          "mse": mse.numpy(),
          "rmse": rmse.numpy(),
          "mape": str(mape.numpy()) + "%",
          "mase": mase.numpy()}

# %% [markdown]
# The following code evaluates the naive forecast using the "evaluate_preds" function and assigns the results to the variable "naive_results".

# %%
naive_results = evaluate_preds(y_true=y_test[1:],
                               y_pred=naive_forecast)
naive_results
# Out:
# {'mae': 0.045757245,
#  'mse': 0.006605717,
#  'rmse': 0.08127556,
#  'mape': '5.231245%',
#  'mase': 0.99672693}

# %% [markdown]
# The code calculates the average price of ADA in the test dataset using the "reduce_mean" function.

# %%
# Find average price of ADA in test dataset
tf.reduce_mean(y_test).numpy()
# Out:
# 0.8121147189090908

# %% [markdown]
# **Create Windows & Horizon**
#
# The next code sets the horizon and window size for the forecast.

# %%
HORIZON = 1 # predict 1 step at a time
WINDOW_SIZE = 7 # use a week worth of timesteps to predict the horizon

# %% [markdown]
# The following code defines a function called "get_labelled_windows" that creates labels for a windowed dataset. It takes an input array and a horizon parameter (default is 1) and returns the input array without the last horizon elements and the last horizon elements as labels.

# %%
# Create function to label windowed data
def get_labelled_windows(x, horizon=1):
  """
  Creates labels for windowed dataset.

  E.g. if horizon=1 (default)
  Input: [1, 2, 3, 4, 5, 6] -> Output: ([1, 2, 3, 4, 5], [6])
  """
  return x[:, :-horizon], x[:, -horizon:]

# %% [markdown]
# The code tests the "get_labelled_windows" function by passing a sample input array and horizon value and prints the window and label.

# %%
# Test out the window labelling function
test_window, test_label = get_labelled_windows(tf.expand_dims(tf.range(8)+1, axis=0), horizon=HORIZON)
print(f"Window: {tf.squeeze(test_window).numpy()} -> Label: {tf.squeeze(test_label).numpy()}")
# Out:
# Window: [1 2 3 4 5 6 7] -> Label: 8

# %% [markdown]
# Now we will perform the following code. It defines a function called "make_windows" that turns a 1D array into a windowed dataset. It takes an input array, a window size, and a horizon parameter (default is 1) and returns the input array split into windows and labels.

# %%
# Create function to view NumPy arrays as windows
def make_windows(x, window_size=7, horizon=1):
  """
  Turns a 1D array into a 2D array of sequential windows of window_size.
  """
  # 1. Create a window of specific window_size (add the horizon on the end for later labelling)
  window_step = np.expand_dims(np.arange(window_size+horizon), axis=0)
  # print(f"Window step:\n {window_step}")

  # 2. Create a 2D array of multiple window steps (minus 1 to account for 0 indexing)
  window_indexes = window_step + np.expand_dims(np.arange(len(x)-(window_size+horizon-1)), axis=0).T # create 2D array of windows of size window_size
  # print(f"Window indexes:\n {window_indexes[:3], window_indexes[-3:], window_indexes.shape}")

  # 3. Index on the target array (time series) with 2D array of multiple window steps
  windowed_array = x[window_indexes]

  # 4. Get the labelled windows
  windows, labels = get_labelled_windows(windowed_array, horizon=horizon)

  return windows, labels

# %% [markdown]
# The following code tests the "make_windows" function by passing a sample input array and window size and prints the windows and labels.

# %%
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (1367, 1367)

# %% [markdown]
# The next code shows the first 3 windows and labels in the dataset, providing a glimpse of the input-output pairs for the forecasting task.

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [0.0259318 0.0208158 0.0219315 0.0214887 0.0185391 0.0209409 0.0204772] -> Label: [0.0221137]
# Window: [0.0208158 0.0219315 0.0214887 0.0185391 0.0209409 0.0204772 0.0221137] -> Label: [0.0215313]
# Window: [0.0219315 0.0214887 0.0185391 0.0209409 0.0204772 0.0221137 0.0215313] -> Label: [0.0225195]

# %% [markdown]
# Now we will view the last 3 windows and labels in the dataset to further examine the input-output pairs.

# %%
# View the last 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i-3]} -> Label: {full_labels[i-3]}")
# Out:
# Window: [1.33520171 1.32475207 1.36843749 1.3834715  1.33561147 1.39439704
#  1.40683592] -> Label: [1.4581844]
# Window: [1.32475207 1.36843749 1.3834715  1.33561147 1.39439704 1.40683592
#  1.4581844 ] -> Label: [1.4048981]
# Window: [1.36843749 1.3834715  1.33561147 1.39439704 1.40683592 1.4581844
#  1.4048981 ] -> Label: [1.41805266]

# %% [markdown]
# **Train-Test-Split**
#
# The following code defines a function called "make_train_test_splits" that splits the windows and labels into train and test sets. It takes the windows, labels, and a test split ratio as input and returns the train windows, test windows, train labels, and test labels.

# %%
# Make the train/test splits
def make_train_test_splits(windows, labels, test_split=0.2):
  """
  Splits matching pairs of windows and labels into train and test splits.
  """
  split_size = int(len(windows) * (1-test_split)) # this will default to 80% train/20% test
  train_windows = windows[:split_size]
  train_labels = labels[:split_size]
  test_windows = windows[split_size:]
  test_labels = labels[split_size:]
  return train_windows, test_windows, train_labels, test_labels

# %% [markdown]
# Now we will perform the following code. It calls the "make_train_test_splits" function to create the train and test splits from the full windows and labels dataset. It also displays the lengths of the train and test data.

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (1093, 274, 1093, 274)

# %%
train_windows[:5], train_labels[:5]
# Out:
# (array([[0.0259318, 0.0208158, 0.0219315, 0.0214887, 0.0185391, 0.0209409,
#          0.0204772],
#         [0.0208158, 0.0219315, 0.0214887, 0.0185391, 0.0209409, 0.0204772,
#          0.0221137],
#         [0.0219315, 0.0214887, 0.0185391, 0.0209409, 0.0204772, 0.0221137,
#          0.0215313],
#         [0.0214887, 0.0185391, 0.0209409, 0.0204772, 0.0221137, 0.0215313,
#          0.0225195],
#         [0.0185391, 0.0209409, 0.0204772, 0.0221137, 0.0215313, 0.0225195,
#          0.0262521]]),
#  array([[0.0221137],
#         [0.0215313],
#         [0.0225195],
#         [0.0262521],
#         [0.033641 ]]))

# %% [markdown]
# The next code defines a function called "create_model_checkpoint" that creates a ModelCheckpoint callback. It takes the model name and a save path as input and returns the ModelCheckpoint callback object. This callback is useful for saving the best-performing model during training.

# %%
import os

# Create a function to implement a ModelCheckpoint callback with a specific filename
def create_model_checkpoint(model_name, save_path="model_experiments"):
  return tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(save_path, model_name), # create filepath to save model
                                            verbose=1, # only output a limited amount of text
                                            save_best_only=True
                                           ) # save only the best model to file

# %%
train_windows.shape,test_windows.shape,train_labels.shape,test_labels.shape
# Out:
# ((1093, 7), (274, 7), (1093, 1), (274, 1))

# %% [markdown]
# **Model 1: Dense model (window = 7, horizon = 1)**
#
# Now we will perform the following code. It constructs a sequential model with two dense layers: one with 128 units and ReLU activation and another with a number of units equal to the horizon value and linear activation. It compiles the model with the mean absolute error (MAE) loss function, Adam optimizer, and MAE metric. It then fits the model on the train windows and labels for a specified number of epochs, using the test windows and labels as validation data. The ModelCheckpoint callback is included to save the best model during training.

# %%
import tensorflow as tf
from tensorflow.keras import layers

# %%
# Set random seed for as reproducible results as possible
tf.random.set_seed(42)

# Construct model
model_1 = tf.keras.Sequential([
  layers.Dense(128, activation="relu"),
  layers.Dense(HORIZON, activation="linear") # linear activation is the same as having no activation
], name="model_1_dense") # give the model a name so we can save it

# Compile model
model_1.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["mae"]) # we don't necessarily need this when the loss function is already MAE

# Fit model
model_1.fit(x=train_windows, # train windows of 7 timesteps of ADA prices
            y=train_labels, # horizon value of 1 (using the previous 7 timesteps to predict next day)
            epochs=100,
            verbose=1,
            batch_size=128,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model_name=model_1.name)]) # create ModelCheckpoint callback to save best model

# %% [markdown]
# The code evaluates the trained model on the test windows and labels and displays the evaluation results.

# %%
# Evaluate model on test data
model_1.evaluate(test_windows, test_labels)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0564 - mae: 0.0564
# [0.056407734751701355, 0.056407734751701355]

# %% [markdown]
# Now we load the saved best-performing model (model_1) and evaluate it on the test windows and labels.

# %%
# Load in saved best performing model_1 and evaluate on test data
model_1 = tf.keras.models.load_model("model_experiments/model_1_dense")
model_1.evaluate(test_windows, test_labels)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0488 - mae: 0.0488
# [0.04876912385225296, 0.04876912385225296]

# %% [markdown]
# The following code defines a function called "make_preds" that uses a trained model to make predictions on input data. It takes the model and input data as input and returns the model's predictions.

# %%
def make_preds(model, input_data):
  """
  Uses model to make predictions on input_data.

  Parameters
  ----------
  model: trained model
  input_data: windowed input data (same kind of data model was trained on)

  Returns model predictions on input_data.
  """
  forecast = model.predict(input_data)
  return tf.squeeze(forecast) # return 1D array of predictions

# %% [markdown]
# Now we will make predictions using model_1 on the test dataset and view the results. It displays the length of the predictions and the first 10 values.

# %%
# Make predictions using model_1 on the test dataset and view the results
model_1_preds = make_preds(model_1, test_windows)
len(model_1_preds), model_1_preds[:10]
# Out:
# 9/9 [==============================] - 0s 2ms/step
# (274,
#  <tf.Tensor: shape=(10,), dtype=float32, numpy=
#  array([0.10029618, 0.09673221, 0.09618568, 0.09756378, 0.1036554 ,
#         0.10765885, 0.10972828, 0.11289338, 0.11212   , 0.11064059],
#        dtype=float32)>)

# %% [markdown]
# The code evaluates the predictions of model_1 using the "evaluate_preds" function and assigns the results to the variable "model_1_results".

# %%
# Evaluate preds
model_1_results = evaluate_preds(y_true=tf.squeeze(test_labels), # reduce to right shape
                                 y_pred=model_1_preds)
model_1_results
# Out:
# {'mae': 0.048769124,
#  'mse': 0.0068787704,
#  'rmse': 0.08293835,
#  'mape': '5.6012645%',
#  'mase': 1.0623344}

# %% [markdown]
# The code sets an offset value and plots the test data and model_1's predictions with the specified offset using the "plot_time_series" function.

# %%
offset = 150
plt.figure(figsize=(10, 7))
# Account for the test_window offset and index into test_labels to ensure correct plotting
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], start=offset, label="Test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_1_preds, start=offset, format="-", label="model_1_preds")

# %% [markdown]
# **Model 2: Dense (window = 30, horizon = 1)**

# %% [markdown]
# The horizon and window size for the forecast are set.

# %%
HORIZON = 1 # predict one step at a time
WINDOW_SIZE = 30 # use 30 timesteps in the past

# %% [markdown]
# Now we will perform the following code. It calls the "make_windows" function to create windowed data with the specified horizon and window size from the prices array. It also displays the lengths of the windows and labels.

# %%
# Make windowed data with appropriate horizon and window sizes
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (1344, 1344)

# %%
# Make train and testing windows
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(windows=full_windows, labels=full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (1075, 269, 1075, 269)

# %% [markdown]
# The code sets the random seed for reproducibility and creates model_2, which is similar to model_1 but with a different data input.
#
# Now we will fit model_2 on the train windows and labels, using the test windows and labels as validation data. The ModelCheckpoint callback is included to save the best model during training.

# %%
tf.random.set_seed(42)

# Create model (same model as model 1 but data input will be different)
model_2 = tf.keras.Sequential([
  layers.Dense(128, activation="relu"),
  layers.Dense(HORIZON) # need to predict horizon number of steps into the future
], name="model_2_dense")

model_2.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

model_2.fit(train_windows,
            train_labels,
            epochs=100,
            batch_size=128,
            verbose=1,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model_name=model_2.name)])

# %% [markdown]
# The code evaluates model_2 on the test windows and labels and displays the evaluation results.

# %%
# Evaluate model 2 preds
model_2.evaluate(test_windows, test_labels)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0598
# 0.059781163930892944

# %% [markdown]
# Now we load the saved best-performing model (model_2) and evaluate it on the test windows and labels.

# %%
# Load in best performing model
model_2 = tf.keras.models.load_model("model_experiments/model_2_dense/")
model_2.evaluate(test_windows, test_labels)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0504
# 0.05038174241781235

# %% [markdown]
# The following code uses model_2 to make predictions on the test windows and assigns the predictions to the variable "model_2_preds".

# %%
# Get forecast predictions
model_2_preds = make_preds(model_2,
                           input_data=test_windows)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %% [markdown]
# The code evaluates the predictions of model_2 using the "evaluate_preds" function and assigns the results to the variable "model_2_results".

# %%
# Evaluate results for model 2 predictions
model_2_results = evaluate_preds(y_true=tf.squeeze(test_labels), # remove 1 dimension of test labels
                                 y_pred=model_2_preds)
model_2_results
# Out:
# {'mae': 0.050381746,
#  'mse': 0.0076984703,
#  'rmse': 0.08774093,
#  'mape': '5.902663%',
#  'mase': 1.0785437}

# %% [markdown]
# The code sets an offset value and plots the test data and model_2's predictions with the specified offset using the "plot_time_series" function.

# %%
offset = 150
plt.figure(figsize=(10, 7))
# Account for the test_window offset
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], start=offset, label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_2_preds, start=offset, format="-", label="model_2_preds")

# %% [markdown]
# **Model 3: Dense (window = 30, horizon = 7)**

# %% [markdown]
# The code sets the horizon and window size for the forecast.
#
# Then we will perform the following code. It calls the "make_windows" function to create windowed data with the specified window size and horizon from the prices array. It also displays the lengths of the windows and labels.

# %%
HORIZON = 7
WINDOW_SIZE = 30

full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (1338, 1338)

# %% [markdown]
# The next code calls the "make_train_test_splits" function to split the full windows and labels into train and test sets. It assigns the train and test windows and labels to the corresponding variables and displays their lengths.

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(windows=full_windows, labels=full_labels, test_split=0.2)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (1070, 268, 1070, 268)

# %%
train_windows.shape, train_labels.shape
# Out:
# ((1070, 30), (1070, 7))

# %% [markdown]
# Now we will create model_3, which is similar to model_1 but with a different input size. It is a sequential model with two dense layers: one with 128 units and ReLU activation and another with a number of units equal to the horizon value. The model is compiled with the mean absolute error (MAE) loss function and Adam optimizer. Now we will fit model_3 on the train windows and labels, using the test windows and labels as validation data. The ModelCheckpoint callback is included to save the best model during training.

# %%
tf.random.set_seed(42)

# Create model (same as model_1 except with different data input size)
model_3 = tf.keras.Sequential([
  layers.Dense(128, activation="relu"),
  layers.Dense(HORIZON)
], name="model_3_dense")

model_3.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

model_3.fit(train_windows,
            train_labels,
            batch_size=128,
            epochs=100,
            verbose=0,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model_name=model_3.name)])

# %% [markdown]
# The code evaluates model_3 on the test windows and labels and displays the evaluation results.

# %%
# How did our model with a larger window size and horizon go?
model_3.evaluate(test_windows, test_labels)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1426
# 0.14260293543338776

# %% [markdown]
# Now we load the saved best-performing model (model_3) and evaluate it on the test windows and labels.

# %%
# Load in best version of model_3 and evaluate
model_3 = tf.keras.models.load_model("model_experiments/model_3_dense/")
model_3.evaluate(test_windows, test_labels)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1183
# 0.11828247457742691

# %% [markdown]
# The following code uses model_3 to make predictions on the test windows and assigns the predictions to the variable "model_3_preds". It displays the first 5 predictions.

# %%
# The predictions are going to be 7 steps at a time (this is the HORIZON size)
model_3_preds = make_preds(model_3,
                           input_data=test_windows)
model_3_preds[:5]
# Out:
# 9/9 [==============================] - 0s 2ms/step
# <tf.Tensor: shape=(5, 7), dtype=float32, numpy=
# array([[0.09445061, 0.09337676, 0.08728436, 0.09158257, 0.08778784,
#         0.09361177, 0.09120482],
#        [0.09220166, 0.09261726, 0.08831476, 0.08940825, 0.09207423,
#         0.09155558, 0.09029826],
#        [0.09245178, 0.0948672 , 0.09091961, 0.09240381, 0.0949759 ,
#         0.09345219, 0.09077276],
#        [0.0923671 , 0.09656823, 0.0928669 , 0.09342778, 0.09314813,
#         0.09557772, 0.09146215],
#        [0.09817723, 0.10256112, 0.09766041, 0.09948333, 0.09664723,
#         0.0973718 , 0.09511793]], dtype=float32)>

# %% [markdown]
# The code evaluates the predictions of model_3 using the "evaluate_preds" function and assigns the results to the variable "model_3_results".

# %%
# Calculate model_3 results - these are going to be multi-dimensional because
# we're trying to predict more than one step at a time.
model_3_results = evaluate_preds(y_true=tf.squeeze(test_labels),
                                 y_pred=model_3_preds)
model_3_results
# Out:
# {'mae': 0.118282475,
#  'mse': 0.033745665,
#  'rmse': 0.1335845,
#  'mape': '13.025146%',
#  'mase': 2.5433986}

# %% [markdown]
# The code sets an offset value and plots the test data and the aggregated model_3's predictions with the specified offset using the "plot_time_series" function.

# %%
offset = 150
plt.figure(figsize=(10, 7))
# Plot model_3_preds by aggregating them (note: this condenses information so the preds will look fruther ahead than the test data)
plot_time_series(timesteps=X_test[-len(test_windows):],
                 values=test_labels[:, 0],
                 start=offset,
                 label="Test_data")
plot_time_series(timesteps=X_test[-len(test_windows):],
                 values=tf.reduce_mean(model_3_preds, axis=1),
                 format="-",
                 start=offset,
                 label="model_3_preds")

# %% [markdown]
# **Comparing all models**

# %%
pd.DataFrame({"naive": naive_results["mae"],
              "horizon_1_window_7": model_1_results["mae"],
              "horizon_1_window_30": model_2_results["mae"],
              "horizon_7_window_30": model_3_results["mae"]}, index=["mae"]).plot(figsize=(10, 7), kind="bar");

# %% [markdown]
# **Model 4: Conv1D**
#
# Now we move on to Model 4, which utilizes Conv1D for the forecasting task.

# %% [markdown]
# The horizon and window size for the forecast are set.

# %%
HORIZON = 1 # predict next day
WINDOW_SIZE = 7 # use previous week worth of data

# %% [markdown]
# Now we will perform the following code. It calls the "make_windows" function to create windowed data with the specified window size and horizon from the prices array. It also displays the lengths of the windows and labels.

# %%
# Create windowed dataset
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (1367, 1367)

# %% [markdown]
# The next code calls the "make_train_test_splits" function to split the full windows and labels into train and test sets. It assigns the train and test windows and labels to the corresponding variables and displays their lengths.

# %%
# Create train/test splits
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (1093, 274, 1093, 274)

# %% [markdown]
# Now we will create model_4, which is a sequential model with a Lambda layer to expand the last dimension of the input, a Conv1D layer with 128 filters, kernel size 5, and ReLU activation, and a Dense layer with a number of units equal to the horizon value. The model is compiled with the mean absolute error (MAE) loss function and Adam optimizer.

# %%
tf.random.set_seed(42)

# Create model
model_4 = tf.keras.Sequential([
  # Create Lambda layer to reshape inputs, without this layer, the model will error
  layers.Lambda(lambda x: tf.expand_dims(x, axis=-1)), # resize the inputs to adjust for window size / Conv1D 3D input requirements
  layers.Conv1D(filters=128, kernel_size=5, padding="causal", activation="relu"),
  layers.Dense(HORIZON)
], name="model_4_conv1D")

# Compile model
model_4.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# %% [markdown]
# Then we will fit model_4 on the train windows and labels, using the test windows and labels as validation data. The ModelCheckpoint callback is included to save the best model during training.

# %%
# Fit model
model_4.fit(train_windows,
            train_labels,
            batch_size=128,
            epochs=100,
            verbose=0,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model_name=model_4.name)])

# %%
model_4.summary()
# Out:
# Model: "model_4_conv1D"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, 7, 1)              0
#
#  conv1d (Conv1D)             (None, 7, 128)            768
#
#  dense_6 (Dense)             (None, 7, 1)              129
#
# =================================================================
# Total params: 897
# Trainable params: 897
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The code loads the saved best-performing model (model_4) and evaluates it on the test windows and labels.

# %%
# Load in best performing Conv1D model and evaluate it on the test data
model_4 = tf.keras.models.load_model("model_experiments/model_4_conv1D")
model_4.evaluate(test_windows, test_labels)
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1047
# 0.10472120344638824

# %% [markdown]
# The following code uses model_4 to make predictions on the test windows and assigns the predictions to the variable "model_4_preds". It displays the first 10 predictions.

# %%
# Make predictions
model_4_preds = make_preds(model_4, test_windows)
model_4_preds[:10]
# Out:
# 9/9 [==============================] - 0s 2ms/step
# <tf.Tensor: shape=(10, 7), dtype=float32, numpy=
# array([[0.09783407, 0.10005305, 0.09800403, 0.09543507, 0.09717546,
#         0.09900076, 0.09984801],
#        [0.09772787, 0.09723225, 0.09359901, 0.09530854, 0.09900076,
#         0.09984801, 0.0962472 ],
#        [0.09487206, 0.09272231, 0.09352773, 0.09736423, 0.09984801,
#         0.0962472 , 0.09698043],
#        [0.09045465, 0.09291478, 0.0960192 , 0.09841732, 0.0962472 ,
#         0.09698043, 0.09866835],
#        [0.09089414, 0.09552401, 0.09724973, 0.09481502, 0.09698043,
#         0.09866835, 0.10330575],
#        [0.09351689, 0.09672002, 0.09329859, 0.09545039, 0.09866835,
#         0.10330575, 0.10612557],
#        [0.09458522, 0.09260719, 0.09383379, 0.09721504, 0.10330575,
#         0.10612557, 0.1080821 ],
#        [0.09035373, 0.09325077, 0.09586968, 0.10199536, 0.10612557,
#         0.1080821 , 0.11147569],
#        [0.09124057, 0.09537007, 0.10107697, 0.10509123, 0.1080821 ,
#         0.11147569, 0.11119863],
#        [0.09334156, 0.10056866, 0.10416728, 0.10693598, 0.11147569,
#         0.11119863, 0.11035764]], dtype=float32)>

# %% [markdown]
# The code evaluates the predictions of model_4 using the "evaluate_preds" function and assigns the results to the variable "model_4_results".

# %%
# Evaluate predictions
model_4_results = evaluate_preds(y_true=test_labels,
                                 y_pred=model_4_preds)
model_4_results
# Out:
# {'mae': 0.1047212,
#  'mse': 0.028933365,
#  'rmse': 0.11698074,
#  'mape': '11.350675%',
#  'mase': 2.2811346}

# %% [markdown]
# The code sets an offset value and plots the test data and model_4's predictions with the specified offset using the "plot_time_series" function.

# %%
offset = 0
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], start=offset, label="Test_data")
# Checking the shape of model_3_preds results in [n_test_samples, HORIZON] (this will screw up the plot)
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_4_preds, start=offset, format="-",label="model_4_preds")

# %% [markdown]
# **Model 5: RNN (LSTM)**
#
# Now we will build model_5 using the Functional API. It takes inputs of shape (WINDOW_SIZE) and applies a Lambda layer to expand the input dimension. Then, two LSTM layers with 128 units and ReLU activation are added, followed by a Dense layer with 32 units and ReLU activation. The output layer has a number of units equal to the horizon value. The model is compiled with the mean absolute error (MAE) loss function and Adam optimizer.

# %%
tf.random.set_seed(42)

# Let's build an LSTM model with the Functional API
inputs = layers.Input(shape=(WINDOW_SIZE))
x = layers.Lambda(lambda x: tf.expand_dims(x, axis=-1))(inputs) # expand input dimension to be compatible with LSTM
print(x.shape)
x = layers.LSTM(128, activation="relu", return_sequences=True)(x) # this layer will error if the inputs are not the right shape
x = layers.LSTM(128, activation="relu")(x) # using the tanh loss function results in a massive error
print(x.shape)
# Add another optional dense layer (you could add more of these to see if they improve model performance)
x = layers.Dense(32, activation="relu")(x)
output = layers.Dense(HORIZON)(x)
model_5 = tf.keras.Model(inputs=inputs, outputs=output, name="model_5_lstm")

# Compile model
model_5.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())
# Out:
# (None, 7, 1)
# (None, 128)

# %% [markdown]
# Now we will fit model_5 on the train windows and labels, using the test windows and labels as validation data. The ModelCheckpoint callback is included to save the best model during training.

# %%
model_5.fit(train_windows,
            train_labels,
            epochs=100,
            verbose=0,
            batch_size=128,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model_name=model_5.name)])

# %% [markdown]
# The code loads the saved best-performing model (model_5) and evaluates it on the test windows and labels.

# %%
# Load in best version of model 5 and evaluate on the test data
model_5 = tf.keras.models.load_model("model_experiments/model_5_lstm/")
model_5.evaluate(test_windows, test_labels)
# Out:
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0525
# 0.052547015249729156

# %% [markdown]
# The following code uses model_5 to make predictions on the test windows and assigns the predictions to the variable "model_5_preds". It displays the first 10 predictions.

# %%
# Make predictions with our LSTM model
model_5_preds = make_preds(model_5, test_windows)
model_5_preds[:10]
# Out:
# 9/9 [==============================] - 0s 10ms/step
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([0.09819569, 0.09741613, 0.09692778, 0.0975622 , 0.10055254,
#        0.1044206 , 0.10783377, 0.11124931, 0.11253764, 0.1120104 ],
#       dtype=float32)>

# %% [markdown]
# The code evaluates the predictions of model_5 using the "evaluate_preds" function and assigns the results to the variable "model_5_results".

# %%
# Evaluate model 5 preds
model_5_results = evaluate_preds(y_true=tf.squeeze(test_labels),
                                 y_pred=model_5_preds)
model_5_results
# Out:
# {'mae': 0.052547015,
#  'mse': 0.008449335,
#  'rmse': 0.091920264,
#  'mape': '6.0407605%',
#  'mase': 1.144628}

# %% [markdown]
# The code sets an offset value and plots the test data and model_5's predictions with the specified offset using the "plot_time_series" function.

# %%
offset = 0
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], start=offset, label="Test_data")
# Checking the shape of model_3_preds results in [n_test_samples, HORIZON] (this will screw up the plot)
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_5_preds, start=offset, format="-",label="model_5_preds")

# %% [markdown]
# And so far all of our models have been trained on a single variable (also called univariate time series): the historical price of ADA.

# %% [markdown]
# **Model 6: Creating an ensemble (stacking different models together)**

# %%
HORIZON = 1 # how far to predict forward
WINDOW_SIZE = 7 # how far to lookback

# %%
ada_prices.head()
# Out:
#                Price
# Date
# 2017-10-02  0.025932
# 2017-10-03  0.020816
# 2017-10-04  0.021931
# 2017-10-05  0.021489
# 2017-10-06  0.018539

# %% [markdown]
# The code block adds lag features to a dataframe by shifting the "Price" column, creating new columns to capture previous values. This is important for time series analysis as it allows the model to consider historical information.

# %%
# Add windowed columns
ada_prices_win = ada_prices.copy()
for i in range(WINDOW_SIZE):
  ada_prices_win[f"Price+{i+1}"] = ada_prices_win["Price"].shift(periods=i+1)
ada_prices_win.dropna().head()
# Out:
#                Price   Price+1   Price+2   Price+3   Price+4   Price+5  \
# Date
# 2017-10-09  0.022114  0.020477  0.020941  0.018539  0.021489  0.021931
# 2017-10-10  0.021531  0.022114  0.020477  0.020941  0.018539  0.021489
# 2017-10-11  0.022520  0.021531  0.022114  0.020477  0.020941  0.018539
# 2017-10-12  0.026252  0.022520  0.021531  0.022114  0.020477  0.020941
# 2017-10-13  0.033641  0.026252  0.022520  0.021531  0.022114  0.020477
#
#              Price+6   Price+7
# Date
# 2017-10-09  0.020816  0.025932
# 2017-10-10  0.021931  0.020816
# 2017-10-11  0.021489  0.021931
# 2017-10-12  0.018539  0.021489
# 2017-10-13  0.020941  0.018539

# %% [markdown]
# Next, the code prepares the features and labels for training and testing. It splits the data into train and test sets, allocating 80% for training and 20% for testing. This ensures that the model is trained on a substantial portion of the data and evaluated on unseen data.

# %%
# Make features and labels
X = ada_prices_win.dropna().drop("Price", axis=1)
y = ada_prices_win.dropna()["Price"]

# Make train and test sets
split_size = int(len(X) * 0.8)
X_train, y_train = X[:split_size], y[:split_size]
X_test, y_test = X[split_size:], y[split_size:]
len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (1093, 1093, 274, 274)

# %% [markdown]
# The code creates train and test datasets as tensor Datasets, combining features and labels. Batching and prefetching optimize performance by processing multiple samples together and overlapping data preprocessing and model training steps. These datasets are essential for training and evaluating time series models, enabling efficient data feeding and accurate model training. Batching and prefetching enhance processing speed and efficiency, improving overall model performance.

# %%
# 1. Turn train and test arrays into tensor Datasets
train_features_dataset = tf.data.Dataset.from_tensor_slices(X_train)
train_labels_dataset = tf.data.Dataset.from_tensor_slices(y_train)

test_features_dataset = tf.data.Dataset.from_tensor_slices(X_test)
test_labels_dataset = tf.data.Dataset.from_tensor_slices(y_test)

# 2. Combine features & labels
train_dataset = tf.data.Dataset.zip((train_features_dataset, train_labels_dataset))
test_dataset = tf.data.Dataset.zip((test_features_dataset, test_labels_dataset))

# 3. Batch and prefetch for optimal performance
BATCH_SIZE = 1024
train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

train_dataset, test_dataset
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None,), dtype=tf.float64, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None,), dtype=tf.float64, name=None))>)

# %% [markdown]
# Now we define the "get_ensemble_models" function, which returns a list of trained models. The function creates multiple models with different loss functions and fits them on the train data for a specified number of iterations and epochs.

# %%
def get_ensemble_models(horizon=HORIZON,
                        train_data=train_dataset,
                        test_data=test_dataset,
                        num_iter=10,
                        num_epochs=100,
                        loss_fns=["mae", "mse", "mape"]):
  """
  Returns a list of num_iter models each trained on MAE, MSE and MAPE loss.

  For example, if num_iter=10, a list of 30 trained models will be returned:
  10 * len(["mae", "mse", "mape"]).
  """
  # Make empty list for trained ensemble models
  ensemble_models = []

  # Create num_iter number of models per loss function
  for i in range(num_iter):
    # Build and fit a new model with a different loss function
    for loss_function in loss_fns:
      print(f"Optimizing model by reducing: {loss_function} for {num_epochs} epochs, model number: {i}")

      # Construct a simple model (similar to model_1)
      model = tf.keras.Sequential([
        # Initialize layers with normal (Gaussian) distribution so we can use the models for prediction
        # interval estimation later: https://www.tensorflow.org/api_docs/python/tf/keras/initializers/HeNormal
        layers.Dense(128, kernel_initializer="he_normal", activation="relu"),
        layers.Dense(128, kernel_initializer="he_normal", activation="relu"),
        layers.Dense(HORIZON)
      ])

      # Compile simple model with current loss function
      model.compile(loss=loss_function,
                    optimizer=tf.keras.optimizers.Adam(),
                    metrics=["mae", "mse"])

      # Fit model
      model.fit(train_data,
                epochs=num_epochs,
                verbose=1,
                validation_data=test_data,
                # Add callbacks to prevent training from going/stalling for too long
                callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                                            patience=200,
                                                            restore_best_weights=True),
                           tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",
                                                                patience=100,
                                                                verbose=1)])

      # Append fitted model to list of ensemble models
      ensemble_models.append(model)

  return ensemble_models # return list of trained models

# %% [markdown]
# Now we will call the "get_ensemble_models" function to get a list of trained ensemble models. The function is called with the specified parameters, and the execution time is displayed.

# %%
# %%time
# Get list of trained ensemble models
ensemble_models = get_ensemble_models(num_iter=5,
                                      num_epochs=1000)
# Out:
# Optimizing model by reducing: mae for 1000 epochs, model number: 0
# Epoch 1/1000
# 2/2 [==============================] - 2s 172ms/step - loss: 0.1299 - mae: 0.1299 - mse: 0.0435 - val_loss: 0.0889 - val_mae: 0.0889 - val_mse: 0.0236 - lr: 0.0010
# Epoch 2/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0411 - mae: 0.0411 - mse: 0.0033 - val_loss: 0.1604 - val_mae: 0.1604 - val_mse: 0.0570 - lr: 0.0010
# Epoch 3/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0525 - mae: 0.0525 - mse: 0.0053 - val_loss: 0.2064 - val_mae: 0.2064 - val_mse: 0.0802 - lr: 0.0010
# Epoch 4/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0214 - mae: 0.0214 - mse: 0.0023 - val_loss: 0.3734 - val_mae: 0.3734 - val_mse: 0.2296 - lr: 0.0010
# Epoch 5/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0418 - mae: 0.0418 - mse: 0.0062 - val_loss: 0.2060 - val_mae: 0.2060 - val_mse: 0.0788 - lr: 0.0010
# Epoch 6/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0187 - mae: 0.0187 - mse: 0.0021 - val_loss: 0.0833 - val_mae: 0.0833 - val_mse: 0.0200 - lr: 0.0010
# Epoch 7/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0267 - mae: 0.0267 - mse: 0.0017 - val_loss: 0.0773 - val_mae: 0.0773 - val_mse: 0.0177 - lr: 0.0010
# Epoch 8/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.
1000
# 2/2 [==============================] - 0s 20ms/step - loss: 4.3699 - mae: 0.0063 - mse: 3.3642e-04 - val_loss: 5.6736 - val_mae: 0.0518 - val_mse: 0.0079 - lr: 1.0000e-04
# Epoch 287/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 4.3925 - mae: 0.0064 - mse: 3.3655e-04 - val_loss: 5.6637 - val_mae: 0.0517 - val_mse: 0.0079 - lr: 1.0000e-04
# Epoch 288/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 4.4046 - mae: 0.0064 - mse: 3.3674e-04 - val_loss: 5.7090 - val_mae: 0.0522 - val_mse: 0.0080 - lr: 1.0000e-04
# Epoch 289/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 4.3715 - mae: 0.0063 - mse: 3.3615e-04 - val_loss: 5.7233 - val_mae: 0.0523 - val_mse: 0.0081 - lr: 1.0000e-04
# Epoch 290/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 4.4518 - mae: 0.0065 - mse: 3.5711e-04
# Epoch 290: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 2/2 [==============================] - 0s 24ms/step - loss: 4.3678 - mae: 0.0063 - mse: 3.3615e-04 - val_loss: 5.6729 - val_mae: 0.0518 - val_mse: 0.0079 - lr: 1.0000e-04
# CPU times: user 3min 20s, sys: 17.5 s, total: 3min 37s
# Wall time: 4min

# %% [markdown]
# Now we define the "make_ensemble_preds" function, which takes a list of trained models and input data and returns a list of predictions from each model.

# %%
# Create a function which uses a list of trained models to make and return a list of predictions
def make_ensemble_preds(ensemble_models, data):
  ensemble_preds = []
  for model in ensemble_models:
    preds = model.predict(data) # make predictions with current ensemble model
    ensemble_preds.append(preds)
  return tf.constant(tf.squeeze(ensemble_preds))

# %% [markdown]
# The code calls the "make_ensemble_preds" function to obtain a list of ensemble predictions using the ensemble models and the test dataset.

# %%
# Create a list of ensemble predictions
ensemble_preds = make_ensemble_preds(ensemble_models=ensemble_models,
                                     data=test_dataset)
ensemble_preds
# Out:
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# <tf.Tensor: shape=(15, 274), dtype=float32, numpy=
# array([[0.10287516, 0.09824912, 0.09630728, ..., 1.4257078 , 1.4528536 ,
#         1.4131612 ],
#        [0.1004405 , 0.09498329, 0.0945432 , ..., 1.3453251 , 1.4274441 ,
#         1.3296717 ],
#        [0.10047708, 0.09595764, 0.09500542, ..., 1.386782  , 1.4483173 ,
#         1.4034612 ],
#        ...,
#        [0.10084718, 0.09743422, 0.09604332, ..., 1.3837025 , 1.4423808 ,
#         1.3718587 ],
#        [0.09974952, 0.09344491, 0.09210666, ..., 1.3609471 , 1.4162825 ,
#         1.368701  ],
#        [0.09775432, 0.09388386, 0.09436322, ..., 1.4227644 , 1.4595591 ,
#         1.4127909 ]], dtype=float32)>

# %% [markdown]
# The code evaluates the ensemble model(s) predictions using the "evaluate_preds" function, comparing the true labels (y_test) with the median of the ensemble predictions. The results are assigned to the variable "ensemble_results".

# %%
# Evaluate ensemble model(s) predictions
ensemble_results = evaluate_preds(y_true=y_test,
                                  y_pred=np.median(ensemble_preds, axis=0)) # take the median across all ensemble predictions
ensemble_results
# Out:
# {'mae': 0.047311705,
#  'mse': 0.006430411,
#  'rmse': 0.08018984,
#  'mape': '5.3707657%',
#  'mase': 1.0305876}

# %% [markdown]
# **Plotting the prediction intervals (uncertainty estimates)**
#
# Now we define the "get_upper_lower" function, which calculates the upper and lower bounds of the prediction intervals based on the standard deviation of the ensemble predictions. The code then calls the "get_upper_lower" function to obtain the upper and lower bounds of the prediction intervals.

# %%
# Find upper and lower bounds of ensemble predictions
def get_upper_lower(preds): # 1. Take the predictions of multiple randomly initialized deep learning neural networks

  # 2. Measure the standard deviation of the predictions
  std = tf.math.reduce_std(preds, axis=0)

  # 3. Multiply the standard deviation by 1.96
  interval = 1.96 * std # https://en.wikipedia.org/wiki/1.96

  # 4. Get the prediction interval upper and lower bounds
  preds_mean = tf.reduce_mean(preds, axis=0)
  lower, upper = preds_mean - interval, preds_mean + interval
  return lower, upper

# Get the upper and lower bounds of the 95%
lower, upper = get_upper_lower(preds=ensemble_preds)

# %% [markdown]
# The code calculates the median values of the ensemble predictions.
#
# Finally, the code plots the test data, the median of the ensemble predictions, and the prediction intervals using the "plot_time_series" function.

# %%
# Get the median values of our ensemble preds
ensemble_median = np.median(ensemble_preds, axis=0)

# Plot the median of our ensemble preds along with the prediction intervals (where the predictions fall between)
offset=150
plt.figure(figsize=(10, 7))
plt.plot(X_test.index[offset:], y_test[offset:], "g", label="Test Data")
plt.plot(X_test.index[offset:], ensemble_median[offset:], "k-", label="Ensemble Median")
plt.xlabel("Date")
plt.ylabel("ADA Price")
plt.fill_between(X_test.index[offset:],
                 (lower)[offset:],
                 (upper)[offset:], label="Prediction Intervals")
plt.legend(loc="upper left", fontsize=14);

# %% [markdown]
# **Compare Models**
#
# The code compares the results of different models, including the naive model and the models trained in previous sections. The results are sorted by mean absolute error (MAE) and plotted in a bar chart.

# %%
# Compare different model results (w = window, h = horizon, e.g. w=7 means a window size of 7)
model_results = pd.DataFrame({"naive_model": naive_results,
                              "model_1_dense_w7_h1": model_1_results,
                              "model_2_dense_w30_h1": model_2_results,
                              "model_3_dense_w30_h7": model_3_results,
                              "model_4_CONV1D": model_4_results,
                              "model_5_LSTM": model_5_results,
                              "model_6_ensemble": ensemble_results,
                             }).T

model_results = model_results.sort_values(by="mae")
model_results.head(10)
# Out:
#                            mae       mse      rmse        mape      mase
# naive_model           0.045757  0.006606  0.081276   5.231245%  0.996727
# model_6_ensemble      0.047312   0.00643   0.08019  5.3707657%  1.030588
# model_1_dense_w7_h1   0.048769  0.006879  0.082938  5.6012645%  1.062334
# model_2_dense_w30_h1  0.050382  0.007698  0.087741   5.902663%  1.078544
# model_5_LSTM          0.052547  0.008449   0.09192  6.0407605%  1.144628
# model_4_CONV1D        0.104721  0.028933  0.116981  11.350675%  2.281135
# model_3_dense_w30_h7  0.118282  0.033746  0.133584  13.025146%  2.543399

# %%
# Sort model results by MAE and plot them
model_results[["mae"]].sort_values(by="mae").plot(figsize=(10, 7), kind="bar");

# %% [markdown]
# **Make a multivariate time series**
#
#
# In the following code, we will perform multivariate time series forecasting using input features such as 'Open', 'Low', 'High', and 'Volume', and the target variable 'Close'. This approach allows us to leverage multiple variables to predict the future value of the target variable.

# %% [markdown]
# The code reads a CSV file containing cryptocurrency price data and parses the dates in the "Date" column.

# %%
# Load the dataset
data = pd.read_csv("/kaggle/input/cryptocurrencypricehistory/coin_Cardano.csv")

# Convert 'Date' to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Remove time part from 'Date' and set 'Date' as index
data['Date'] = data['Date'].dt.date
data.set_index('Date', inplace=True)

# Print the first 5 rows
data.head()
# Out:
#             SNo     Name Symbol      High       Low      Open     Close  \
# Date
# 2017-10-02    1  Cardano    ADA  0.030088  0.019969  0.024607  0.025932
# 2017-10-03    2  Cardano    ADA  0.027425  0.020690  0.025757  0.020816
# 2017-10-04    3  Cardano    ADA  0.022806  0.020864  0.020864  0.021931
# 2017-10-05    4  Cardano    ADA  0.022154  0.020859  0.021951  0.021489
# 2017-10-06    5  Cardano    ADA  0.021542  0.018360  0.021359  0.018539
#
#                 Volume     Marketcap
# Date
# 2017-10-02  57641300.0  6.288991e+08
# 2017-10-03  16997800.0  5.396927e+08
# 2017-10-04   9000050.0  5.686195e+08
# 2017-10-05   5562510.0  5.571390e+08
# 2017-10-06   7780710.0  4.806646e+08

# %% [markdown]
# The time part is removed from the "Date" column, and the modified column is set as the index of the data. The data is then scaled using MinMaxScaler for the input features ('Open', 'Low', 'High', 'Volume') and the target variable ('Close')

# %%
from sklearn.preprocessing import MinMaxScaler
x_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
datar = data.copy()
x = datar[['Open', 'Low', 'High', 'Volume']].copy()
y = datar['Close'].copy()

x[['Open', 'Low', 'High', 'Volume']] = x_scaler.fit_transform(x)
y = y_scaler.fit_transform(y.values.reshape(-1, 1))

# %%
x.shape, y.shape
# Out:
# ((1374, 4), (1374, 1))

# %% [markdown]
# The code defines a function called load_data to split the data into training and testing sets, considering a specified sequence length for creating time series samples. The function converts the input data into a suitable format for training an LSTM model.
# The function returns the training and testing sets for both input features and the target variable.

# %%
def load_data(X, seq_len, train_size=0.8):
    amount_of_features = X.shape[1]
    X_mat = X.values
    sequence_length = seq_len + 1
    data = []

    for index in range(len(X_mat) - sequence_length):
        data.append(X_mat[index: index + sequence_length])

    data = np.array(data)
    train_split = int(round(train_size * data.shape[0]))
    train_data = data[:train_split, :]

    x_train = train_data[:, :-1]
    y_train = train_data[:, -1][:,-1]

    x_test = data[train_split:, :-1]
    y_test = data[train_split:, -1][:,-1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], amount_of_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], amount_of_features))

    return x_train, y_train, x_test, y_test

# %% [markdown]
# A window size of 7 is chosen for the time series. The load_data function is used to obtain the training and testing sets.

# %%
window = 7
x['Close'] = y
X_train, y_train, X_test, y_test = load_data(x, window)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1093, 7, 5) (1093,) (273, 7, 5) (273,)

# %% [markdown]
# A plot is created to visualize the open, close, high, and low prices over time.

# %%
plt.figure(figsize=(15, 5));
plt.plot(data.Open.values, color='red', label='open')
plt.plot(data.Close.values, color='green', label='close')
plt.plot(data.High.values, color='yellow', label='high')
plt.plot(data.Low.values, color='blue', label='low')

plt.title('stock')
plt.xlabel('time [days]')
plt.ylabel('price/volume')
plt.legend(loc='best')
plt.show()

# %%
X_train.shape[1], X_train.shape[2]
# Out:
# (7, 5)

# %% [markdown]
# **Model: LSTM**
#
# The code sets a random seed and defines the architecture of the LSTM model using the Sequential API in TensorFlow. The model consists of multiple LSTM layers with dropout regularization to prevent overfitting.
# The output layer is a dense layer with a linear activation function. Early stopping is implemented as a callback to monitor the validation loss and stop training if it doesn't improve for a certain number of epochs. The model is compiled with the Adam optimizer and mean squared error (MSE) loss function. The model is trained on the training set, and the training time is recorded.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.callbacks import EarlyStopping

tf.random.set_seed(42) # set random seed for reproducibility

#LSTM architecture
model = Sequential()
# First LSTM layer with Dropout regularisation
model.add(LSTM(units=50, input_shape=(X_train.shape[1], X_train.shape[2]),return_sequences=True))
model.add(Dropout(0.2))
# Second LSTM layer
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
# Third LSTM layer
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
# Fourth LSTM layer
model.add(LSTM(units=50))
model.add(Dropout(0.5))
# The output layer
model.add(Dense(units=50, kernel_initializer='uniform', activation='tanh'))
model.add(Dense(units=1, kernel_initializer='uniform', activation='linear'))

earlystop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
callbacks_list = [earlystop]

# Compiling the RNN
model.compile(optimizer='adam',loss='mean_squared_error')

# Fitting to the training set
LSTM=model.fit(X_train,y_train,epochs=100,batch_size=35, validation_split=0.05, verbose=1,callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 12s 86ms/step - loss: 0.0041 - val_loss: 4.6854e-05
# Epoch 2/100
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0010 - val_loss: 5.5804e-05
# Epoch 3/100
# 30/30 [==============================] - 1s 23ms/step - loss: 7.1345e-04 - val_loss: 2.6157e-04
# Epoch 4/100
# 30/30 [==============================] - 1s 24ms/step - loss: 7.0407e-04 - val_loss: 3.0545e-05
# Epoch 5/100
# 30/30 [==============================] - 1s 24ms/step - loss: 6.6987e-04 - val_loss: 4.0971e-05
# Epoch 6/100
# 30/30 [==============================] - 1s 24ms/step - loss: 6.2277e-04 - val_loss: 1.8617e-05
# Epoch 7/100
# 30/30 [==============================] - 1s 23ms/step - loss: 6.5435e-04 - val_loss: 2.6911e-05
# Epoch 8/100
# 30/30 [==============================] - 1s 24ms/step - loss: 6.1390e-04 - val_loss: 1.0564e-04
# Epoch 9/100
# 30/30 [==============================] - 1s 25ms/step - loss: 6.2780e-04 - val_loss: 1.7543e-05
# Epoch 10/100
# 30/30 [==============================] - 1s 25ms/step - loss: 7.3044e-04 - val_loss: 3.1126e-05
# Epoch 11/100
# 30/30 [==============================] - 1s 25ms/step - loss: 7.5354e-04 - val_loss: 2.0479e-05
# Epoch 12/100
# 30/30 [==============================] - 1s 24ms/step - loss: 6.8077e-04 - val_loss: 2.8546e-05
# Epoch 13/100
# 30/30 [==============================] - 1s 24ms/step - loss: 7.3448e-04 - val_loss: 1.7328e-05
# Epoch 14/100
# 30/30 [==============================] - 1s 24ms/step - loss: 6.5789e-04 - val_loss: 2.8963e-05
# Epoch 15/100
# 30/30 [==============================] - 1s 26ms/step - loss: 5.5903e-04 - val_loss: 2.6392e-05
# Epoch 16/100
# 30/30 [==============================] - 1s 25ms/step - loss: 5.5368e-04 - val_loss: 3.8231e-05
# Epoch 17/100
# 30/30 [==============================] - 1s 24ms/step - loss: 6.3153e-04 - val_loss: 2.0126e-05
# Epoch 18/100
# 30/30 [==============================] - 1s 24ms/step - loss: 6.4788e-04 - val_loss: 4.7070e-05
# Epoch 19/100
# 30/30 [==============================] - 1s 25ms/step - loss: 7.0458e-04 - val_loss: 1.9965e-05
# Epoch 20/100
# 30/30 [==============================] - 1s 25ms/step - loss: 6.3484e-04 - val_loss: 3.0875e-05
# Epoch 21/100
# 30/30 [==============================] - 1s 24ms/step - loss: 5.4396e-04 - val_loss: 2.1418e-05
# Epoch 22/100
# 30/30 [==============================] - 1s 23ms/step - loss: 6.3868e-04 - val_loss: 1.9385e-05
# Epoch 23/100
# 30/30 [==============================] - 1s 26ms/step - loss: 5.3616e-04 - val_loss: 4.1926e-05
# Epoch 24/100
# 30/30 [==============================] - 1s 30ms/step - loss: 5.4002e-04 - val_loss: 1.5153e-05
# Epoch 25/100
# 30/30 [==============================] - 1s 26ms/step - loss: 4.6984e-04 - val_loss: 1.8446e-05
# Epoch 26/100
# 30/30 [==============================] - 1s 25ms/step - loss: 4.8811e-04 - val_loss: 1.4974e-05
# Epoch 27/100
# 30/30 [==============================] - 1s 24ms/step - loss: 5.6444e-04 - val_loss: 4.4071e-05
# Epoch 28/100
# 30/30 [==============================] - 1s 25ms/step - loss: 7.9546e-04 - val_loss: 5.3147e-05
# Epoch 29/100
# 30/30 [==============================] - 1s 24ms/step - loss: 5.6834e-04 - val_loss: 2.6881e-05
# Epoch 30/100
# 30/30 [==============================] - 1s 25ms/step - loss: 5.0130e-04 - val_loss: 2.0376e-05
# Epoch 31/100
# 30/30 [==============================] - 1s 24ms/step - loss: 4.6056e-04 - val_loss: 1.9325e-05
# Epoch 32/100
# 30/30 [==============================] - 1s 25ms/step - loss: 4.1880e-04 - val_loss: 1.5785e-05
# Epoch 33/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.7368e-04 - val_loss: 4.2290e-05
# Epoch 34/100
# 30/30 [==============================] - 1s 24ms/step - loss: 5.0555e-04 - val_loss: 2.3047e-05
# Epoch 35/100
# 30/30 [==============================] - 1s 25ms/step - loss: 4.3163e-04 - val_loss: 6.0950e-05
# Epoch 36/100
# 30/30 [==============================] - 1s 24ms/step - loss: 4.3335e-04 - val_loss: 4.8475e-05
# Epoch 37/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.8825e-04 - val_loss: 2.5407e-05
# Epoch 38/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.4043e-04 - val_loss: 2.6483e-05
# Epoch 39/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.5806e-04 - val_loss: 4.9182e-05
# Epoch 40/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.9812e-04 - val_loss: 1.6076e-05
# Epoch 41/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.1474e-04 - val_loss: 2.1974e-05
# Epoch 42/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.4654e-04 - val_loss: 4.7899e-05
# Epoch 43/100
# 30/30 [==============================] - 1s 24ms/step - loss: 4.5263e-04 - val_loss: 1.9739e-05
# Epoch 44/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.3079e-04 - val_loss: 2.5128e-05
# Epoch 45/100
# 30/30 [==============================] - 1s 24ms/step - loss: 4.0628e-04 - val_loss: 1.4796e-05
# Epoch 46/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.8711e-04 - val_loss: 1.3075e-05
# Epoch 47/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.5636e-04 - val_loss: 1.7741e-05
# Epoch 48/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.5512e-04 - val_loss: 1.8610e-05
# Epoch 49/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.3682e-04 - val_loss: 2.7266e-05
# Epoch 50/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.4379e-04 - val_loss: 2.6686e-05
# Epoch 51/100
# 30/30 [==============================] - 1s 24ms/step - loss: 4.8750e-04 - val_loss: 1.1778e-05
# Epoch 52/100
# 30/30 [==============================] - 1s 24ms/step - loss: 4.5628e-04 - val_loss: 4.1066e-05
# Epoch 53/100
# 30/30 [==============================] - 1s 25ms/step - loss: 4.1953e-04 - val_loss: 3.3663e-05
# Epoch 54/100
# 30/30 [==============================] - 1s 23ms/step - loss: 2.9949e-04 - val_loss: 3.4314e-05
# Epoch 55/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.1588e-04 - val_loss: 2.6532e-05
# Epoch 56/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.0792e-04 - val_loss: 3.8132e-05
# Epoch 57/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.1916e-04 - val_loss: 2.1994e-05
# Epoch 58/100
# 30/30 [==============================] - 1s 23ms/step - loss: 2.8293e-04 - val_loss: 1.9163e-05
# Epoch 59/100
# 30/30 [==============================] - 1s 23ms/step - loss: 3.3385e-04 - val_loss: 2.8065e-05
# Epoch 60/100
# 30/30 [==============================] - 1s 24ms/step - loss: 4.0717e-04 - val_loss: 4.4982e-05
# Epoch 61/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.3099e-04 - val_loss: 2.2007e-05
# Epoch 62/100
# 30/30 [==============================] - 1s 23ms/step - loss: 3.0567e-04 - val_loss: 1.2435e-05
# Epoch 63/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.4276e-04 - val_loss: 1.0952e-05
# Epoch 64/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.3213e-04 - val_loss: 1.8799e-05
# Epoch 65/100
# 30/30 [==============================] - 1s 23ms/step - loss: 3.7116e-04 - val_loss: 2.7108e-05
# Epoch 66/100
# 30/30 [==============================] - 1s 28ms/step - loss: 2.6343e-04 - val_loss: 7.1248e-05
# Epoch 67/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.1976e-04 - val_loss: 1.2091e-05
# Epoch 68/100
# 30/30 [==============================] - 1s 26ms/step - loss: 2.7819e-04 - val_loss: 2.0370e-05
# Epoch 69/100
# 30/30 [==============================] - 1s 27ms/step - loss: 3.0801e-04 - val_loss: 1.5174e-05
# Epoch 70/100
# 30/30 [==============================] - 1s 26ms/step - loss: 2.4435e-04 - val_loss: 1.0085e-05
# Epoch 71/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.7557e-04 - val_loss: 1.6364e-05
# Epoch 72/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.4984e-04 - val_loss: 1.1361e-05
# Epoch 73/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.7974e-04 - val_loss: 2.0679e-05
# Epoch 74/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.7842e-04 - val_loss: 1.1685e-05
# Epoch 75/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.6355e-04 - val_loss: 1.3484e-05
# Epoch 76/100
# 30/30 [==============================] - 1s 27ms/step - loss: 2.8980e-04 - val_loss: 9.7282e-06
# Epoch 77/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.0069e-04 - val_loss: 2.4775e-05
# Epoch 78/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.4667e-04 - val_loss: 2.6727e-05
# Epoch 79/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.1795e-04 - val_loss: 1.3605e-05
# Epoch 80/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.1920e-04 - val_loss: 1.3708e-05
# Epoch 81/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.1018e-04 - val_loss: 1.1446e-05
# Epoch 82/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.0825e-04 - val_loss: 3.0256e-05
# Epoch 83/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.1901e-04 - val_loss: 1.5108e-05
# Epoch 84/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.7260e-04 - val_loss: 6.7975e-05
# Epoch 85/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.8451e-04 - val_loss: 9.6852e-06
# Epoch 86/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.8290e-04 - val_loss: 1.5014e-05
# Epoch 87/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.6113e-04 - val_loss: 9.9843e-06
# Epoch 88/100
# 30/30 [==============================] - 1s 22ms/step - loss: 2.1783e-04 - val_loss: 9.6919e-06
# Epoch 89/100
# 30/30 [==============================] - 1s 23ms/step - loss: 1.9134e-04 - val_loss: 9.8904e-06
# Epoch 90/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.8694e-04 - val_loss: 1.0812e-05
# Epoch 91/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.4961e-04 - val_loss: 3.6674e-05
# Epoch 92/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.7781e-04 - val_loss: 8.7653e-06
# Epoch 93/100
# 30/30 [==============================] - 1s 23ms/step - loss: 3.1078e-04 - val_loss: 2.5996e-05
# Epoch 94/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.5206e-04 - val_loss: 2.6603e-05
# Epoch 95/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.3345e-04 - val_loss: 1.6039e-05
# Epoch 96/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.7928e-04 - val_loss: 1.6783e-05
# Epoch 97/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.8131e-04 - val_loss: 1.0070e-05
# Epoch 98/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.2321e-04 - val_loss: 4.2405e-05
# Epoch 99/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.6487e-04 - val_loss: 1.2840e-05
# Epoch 100/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.7353e-04 - val_loss: 2.1385e-05

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 7, 50)             11200
#
#  dropout (Dropout)           (None, 7, 50)             0
#
#  lstm_3 (LSTM)               (None, 7, 50)             20200
#
#  dropout_1 (Dropout)         (None, 7, 50)             0
#
#  lstm_4 (LSTM)               (None, 7, 50)             20200
#
#  dropout_2 (Dropout)         (None, 7, 50)             0
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense_54 (Dense)            (None, 50)                2550
#
#  dense_55 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 74,401
# Trainable params: 74,401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The code plots the training loss and validation loss from the model training history using pd.DataFrame(LSTM.history) and the plot() function.

# %%
# %matplotlib inline
losses = pd.DataFrame(LSTM.history)
losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# **Model Prediction**
#
# The code segment uses the trained LSTM model to make predictions on the training and testing data. The predicted stock prices are transformed back to their original scale using y_scaler.inverse_transform(). The original stock prices (trainY, testY) are also transformed back to their original scale.

# %%
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

trainPredict = y_scaler.inverse_transform(trainPredict)
trainY = y_scaler.inverse_transform([y_train])
testPredict = y_scaler.inverse_transform(testPredict)
testY = y_scaler.inverse_transform([y_test])
# Out:
# 35/35 [==============================] - 2s 7ms/step
# 9/9 [==============================] - 0s 7ms/step

# %%
plot_predicted = testPredict.copy()
plot_predicted = plot_predicted.reshape(testPredict.shape[0], testPredict.shape[1])
plot_actual = testY.copy()
plot_actual = plot_actual.reshape(testPredict.shape[0], testPredict.shape[1])
print(plot_actual.shape)
print(plot_predicted.shape)
# Out:
# (273, 1)
# (273, 1)

# %%
plot_x = data.index.copy()

# %% [markdown]
# The actual and predicted values are plotted to visualize the model's performance.

# %%
plt.figure(figsize=(20,7))
plot_x = plot_x[-272:]
plot_x = pd.to_datetime(plot_x)
plt.plot(pd.DataFrame(plot_predicted), label='Predicted')
plt.plot(pd.DataFrame(plot_actual), label='Actual')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# The code calculates the root mean squared error (RMSE) for the training and testing predictions using the mean_squared_error() function from sklearn.metrics.

# %%
from sklearn.metrics import mean_squared_error, r2_score

trainScore = mean_squared_error(trainY[0], trainPredict[:,0]) ** .5
print('Train Score: %.2f RMSE' % (trainScore))
testScore = mean_squared_error(testY[0], testPredict[:,0]) ** .5
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 0.03 RMSE
# Test Score: 0.28 RMSE

# %% [markdown]
# Additional evaluation metrics such as mean absolute error (MAE), mean absolute percentage error (MAPE), and median absolute percentage error (MDAPE) are calculated to assess the model's performance.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error # Packages for measuring model performance / errors

# Get the predicted values
y_pred_scaled = model.predict(X_test)

# Unscale the predicted values
y_pred = y_scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = y_scaler.inverse_transform(y_test.reshape(-1, 1))

# Mean Absolute Error (MAE)
MAE = mean_absolute_error(y_test_unscaled, y_pred)
print(f'Median Absolute Error (MAE): {np.round(MAE, 2)}')

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print(f'Mean Absolute Percentage Error (MAPE): {np.round(MAPE, 2)} %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled)) ) * 100
print(f'Median Absolute Percentage Error (MDAPE): {np.round(MDAPE, 2)} %')
# Out:
# 9/9 [==============================] - 0s 8ms/step
# Median Absolute Error (MAE): 0.2
# Mean Absolute Percentage Error (MAPE): 17.52 %
# Median Absolute Percentage Error (MDAPE): 18.72 %

# %% [markdown]
# The stock price data is reshaped for plotting purposes, and the training and testing predictions are assigned to appropriate variables.

# %%
stock_prices = data.Close.values.astype('float32')
stock_prices = stock_prices.reshape(len(stock_prices), 1)

# %%
trainPredictPlot = np.empty_like(stock_prices)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[22:len(trainPredict)+22, :] = trainPredict

testPredictPlot = np.empty_like(stock_prices)
testPredictPlot[:, :] = np.nan
testPredictPlot[(len(stock_prices) - testPredict.shape[0]):len(stock_prices), :] = testPredict

# %% [markdown]
# Finally, a plot is created to show the actual closing prices, as well as the predicted prices on both the training and testing sets.

# %%
plt.figure(figsize=(20,7))
plt.plot(pd.DataFrame(stock_prices, columns=["close"], index=data.index).close, label='Actual')
plt.plot(pd.DataFrame(trainPredictPlot, columns=["close"], index=data.index).close, label='Training')
plt.plot(pd.DataFrame(testPredictPlot, columns=["close"], index=data.index).close, label='Testing')
plt.legend(loc='best')
plt.show()
